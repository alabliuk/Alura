# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from datetime import date

import warnings
warnings.filterwarnings('ignore')

# %%
df_total = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/COVID-Alura/main/cases-brazil-states.csv')
df_total.head()
# Out:
#    semana        data    pais  ... suspeitos testes  testes_por_100k
# 0       9  2020-02-25  Brazil  ...       NaN    NaN              NaN
# 1       9  2020-02-25  Brazil  ...       NaN    NaN              NaN
# 2       9  2020-02-26  Brazil  ...       NaN    NaN              NaN
# 3       9  2020-02-26  Brazil  ...       NaN    NaN              NaN
# 4       9  2020-02-27  Brazil  ...       NaN    NaN              NaN
#
# [5 rows x 18 columns]

# %%
#retirando estado = total do df
df = df_total[df_total['estado'] != 'TOTAL']

#forçando a converçao de data
df['data'] = pd.to_datetime(df_total['data']).dt.date
df.head()
# Out:
#    semana        data    pais  ... suspeitos testes  testes_por_100k
# 0       9  2020-02-25  Brazil  ...       NaN    NaN              NaN
# 2       9  2020-02-26  Brazil  ...       NaN    NaN              NaN
# 4       9  2020-02-27  Brazil  ...       NaN    NaN              NaN
# 6       9  2020-02-28  Brazil  ...       NaN    NaN              NaN
# 8       9  2020-02-29  Brazil  ...       NaN    NaN              NaN
#
# [5 rows x 18 columns]

# %%
plt.figure(figsize=(20,8))
fig = sns.lineplot(x='data', y='Obitos', hue='estado', data=df)
fig.set_title('Obitos por estado em função do tempo', loc='left', fontsize=24)
fig.set_xlabel('Data', fontsize=24)
fig.set_ylabel('Data', fontsize=24)
# Out:
# Text(0, 0.5, 'Data')

# %%
df_sp = df[df['estado'] == 'SP']
df_sp.head()
# Out:
#    semana        data    pais  ... suspeitos testes  testes_por_100k
# 0       9  2020-02-25  Brazil  ...       NaN    NaN              NaN
# 2       9  2020-02-26  Brazil  ...       NaN    NaN              NaN
# 4       9  2020-02-27  Brazil  ...       NaN    NaN              NaN
# 6       9  2020-02-28  Brazil  ...       NaN    NaN              NaN
# 8       9  2020-02-29  Brazil  ...       NaN    NaN              NaN
#
# [5 rows x 18 columns]

# %%
plt.figure(figsize=(20, 8))
fig = sns.lineplot(x='data', y='Obitos', data=df_sp)
fig.set_title('Óbitos em função do tempo no estado de SP', loc='left', fontsize=24)
fig.set_xlabel('Data', fontsize=24)
fig.set_ylabel('Log Óbitos', fontsize=24)
fig.set_yscale('log')

# %%
#todos os estados
plt.figure(figsize=(20,8))
fig = sns.lineplot(x='data',y='Obitos',hue='estado',data=df)
fig.set_title('Óbitos em função do tempo em todos os estados',loc='left',fontsize=24)
fig.set_xlabel('Data',fontsize=24)
fig.set_ylabel('Log Óbitos',fontsize=24)
fig.set_yscale('log')

# %%
#renderização em grafico de barra (todos os estados)
plt.figure(figsize=(20,8))
fig = sns.barplot(x='data',y='Obitos',hue='estado',data=df)
fig.set_title('Óbitos por estado em função do tempo', loc='left',fontsize=24)
fig.set_xlabel('Data',fontsize=24)
fig.set_ylabel('Óbitos',fontsize=24)
# Out:
# Text(0, 0.5, 'Óbitos')

# %%
#renderização em grafico de barra (apenas SP)
plt.figure(figsize=(20,8))
fig = plt.bar(df_sp.data, df_sp.suspeitos,label='Suspeitos')
plt.bar(df_sp.data,df_sp.recuperados,label='Recuperados')
plt.bar(df_sp['data'],df_sp['Obitos'],label='Óbitos')
plt.xlabel('Data',fontsize=24)
plt.ylabel('Óbitos, Recuperados e Suspeitos no estado de SP',fontsize=24,rotation=90)
plt.legend()
